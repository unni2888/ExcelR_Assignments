# %% [markdown]
# Q.1) A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units. A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level. Please state the assumptions and tests that you carried out to check validity of the assumptions

# %%
from google.colab import files
up= files.upload()
# Out:
#      <input type="file" id="files-74efe80a-515b-4862-a135-8b47f87c2ab0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74efe80a-515b-4862-a135-8b47f87c2ab0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
cutlets= pd.read_csv('Cutlets.csv')
cutlets
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
# Null Hypothesis: There is no significant difference in the diameter of the cutlet between two units.
# Alternate Hypothesis: There is significant difference in the diameter of the cutlet between two units.
# Alpha = 0.05

# %%
UnitA= cutlets['Unit A']
UnitB= cutlets['Unit B']

# %%
from scipy import stats
t, p= stats.ttest_ind(UnitA, UnitB)
print('t statistics =', t)
print('p value =', p)
# Out:
# t statistics = 0.7228688704678063
# p value = 0.4722394724599501

# %%
# Here, p value is greater than Alpha, So, we accept the Null hypothesis.

# %% [markdown]
# Q.2) A hospital wants to determine whether there is any difference in the average Turn Around Time (TAT) of reports of the laboratories on their preferred list. They collected a random sample and recorded TAT for reports of 4 laboratories. TAT is defined as sample collected to report dispatch.
#
# Analyze the data and determine whether there is any difference in average TAT among the different laboratories at 5% significance level.

# %%
from google.colab import files
up= files.upload()
# Out:
#      <input type="file" id="files-58bf60b7-7bec-4272-adfc-1c305b9db0f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58bf60b7-7bec-4272-adfc-1c305b9db0f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
labtat= pd.read_csv('LabTAT.csv')
labtat
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
# Null hypothesis: There is no difference in the average Turn Around Time (TAT) of reports.
# Alternate hypothesis: There is significant difference in the average Turn Around Time (TAT) of reports.
# Alpha = 0.05

# %%
lab1= labtat.iloc[:,0]
lab2= labtat.iloc[:,1]
lab3= labtat.iloc[:,2]
lab4= labtat.iloc[:,3]

# %%
f_stat, p_val = stats.f_oneway(lab1, lab2, lab3, lab4)
print("f statistics =",f_stat)
print("p value =", p_val)
# Out:
# f statistics = 118.70421654401437
# p value = 2.1156708949992414e-57

# %%
# Here, p value is smaller than Alpha, so we reject the Null hypothesis.

# %% [markdown]
# Q.3) Sales of products in four different regions is tabulated for males and females. Find if male-female buyer rations are similar across regions.

# %%
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-4dd3f116-90f2-402c-9b3c-7dc7a82b6c35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4dd3f116-90f2-402c-9b3c-7dc7a82b6c35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
buyer = pd.read_csv('BuyerRatio.csv')
buyer
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
# Null hypothesis: All means are the same.
# Alternate hypothesis: There is significant difference among the means.
# Alpha = 0.05

# %%
import numpy as np
from scipy.stats import chi2_contingency
Observed = np.array([[50, 142, 131, 70], [435, 1523, 1356, 750]])
chi2, pval, df, expected = chi2_contingency(Observed)
print(chi2)
print('p value =',pval)
print(df)
print(expected)
# Out:
# 1.595945538661058
# p value = 0.6603094907091882
# df 3
# [[  42.76531299  146.81287862  131.11756787   72.30424052]
#  [ 442.23468701 1518.18712138 1355.88243213  747.69575948]]

# %%
# Here, pvalue is greater than Alpha, therefore we accept the Null hypothesis.

# %% [markdown]
# Q.4) TeleCall uses 4 centers around the globe to process customer order forms. They audit a certain %  of the customer order forms. Any error in order form renders it defective and has to be reworked before processing.  The manager wants to check whether the defective %  varies by centre. Please analyze the data at 5% significance level and help the manager draw appropriate inferences

# %%
from google.colab import files
op = files.upload()
# Out:
#      <input type="file" id="files-306bca47-b9b9-4f3d-9371-a4d5e6ab5654" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-306bca47-b9b9-4f3d-9371-a4d5e6ab5654">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cof = pd.read_csv('Costomer+OrderForm.csv')
cof
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
# Null hypothesis: The defective % does not varies by centre.
# Alternate hypithesis: The defective % varies by centre.
# Alpha = 0.05

# %%
contingency_table = pd.crosstab(cof['Phillippines'], [cof['Indonesia'], cof['Malta'], cof['India']])


chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)


print("Chi-square statistic: ",chi2_stat)
print("p-value: ",p_val)
print("Degrees of freedom: ",dof)
print("Expected values: \n", expected)
# Out:
# Chi-square statistic:  3.1001395592512266
# p-value:  0.6845505149379718
# Degrees of freedom:  5
# Expected values:
#  [[8.70000000e-01 1.93333333e-01 2.12666667e+00 2.12666667e+00
#   1.74000000e+00 2.19433333e+01]
#  [8.13000000e+00 1.80666667e+00 1.98733333e+01 1.98733333e+01
#   1.62600000e+01 2.05056667e+02]]

# %%
# Here p value is greater than Alpha, so we accept the Null hypothesis.
