# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
corolla1 = pd.read_csv('ToyotaCorolla.csv', encoding = 'unicode_escape')
corolla1.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
corolla1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
corolla1.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Color', 'Automatic', 'cc', 'Doors',
#        'Cylinders', 'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee',
#        'BOVAG_Guarantee', 'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2',
#        'Airco', 'Automatic_airco', 'Boardcomputer', 'CD_Player',
#        'Central_Lock', 'Powered_Windows', 'Power_Steering', 'Radio',
#        'Mistlamps', 'Sport_Model', 'Backseat_Divider', 'Metallic_Rim',
#        'Radio_cassette', 'Tow_Bar'],
#       dtype='object')

# %%
corolla2 = corolla1.drop(['Id', 'Model', 'Mfg_Month', 'Mfg_Year', 'Fuel_Type', 'Met_Color', 'Color', 'Automatic', 'Cylinders', 'Mfr_Guarantee',
                          'BOVAG_Guarantee', 'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco', 'Automatic_airco', 'Boardcomputer', 
                          'CD_Player', 'Central_Lock', 'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps', 'Sport_Model', 'Backseat_Divider', 
                          'Metallic_Rim', 'Radio_cassette', 'Tow_Bar'], axis = 1)

# %%
corolla2.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
corolla2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
corolla2[corolla2.duplicated()]
# Out:
#      Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 113  24950          8  13253  116  2000      5      5            234    1320

# %%
corolla2=corolla2.drop(corolla2.index[113], axis =0)

# %%
corolla2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1435 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1435 non-null   int64
#  1   Age_08_04      1435 non-null   int64
#  2   KM             1435 non-null   int64
#  3   HP             1435 non-null   int64
#  4   cc             1435 non-null   int64
#  5   Doors          1435 non-null   int64
#  6   Gears          1435 non-null   int64
#  7   Quarterly_Tax  1435 non-null   int64
#  8   Weight         1435 non-null   int64
# dtypes: int64(9)
# memory usage: 112.1 KB

# %%
corolla2.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876273 -0.569420  0.314134  0.124375  0.183604
# Age_08_04     -0.876273   1.000000  0.504575 -0.155293 -0.096549 -0.146929
# KM            -0.569420   0.504575  1.000000 -0.332904  0.103822 -0.035193
# HP             0.314134  -0.155293 -0.332904  1.000000  0.035207  0.091803
# cc             0.124375  -0.096549  0.103822  0.035207  1.000000  0.079254
# Doors          0.183604  -0.146929 -0.035193  0.091803  0.079254  1.000000
# Gears          0.063831  -0.005629  0.014890  0.209642  0.014732 -0.160101
# Quarterly_Tax  0.211508  -0.193319  0.283312 -0.302287  0.305982  0.107353
# Weight         0.575869  -0.466484 -0.023969  0.087143  0.335077  0.301734
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063831       0.211508  0.575869
# Age_08_04     -0.005629      -0.193319 -0.466484
# KM             0.014890       0.283312 -0.023969
# ...

# %%
sns.set_palette('viridis')

sns.set_style(style='whitegrid')
sns.pairplot(corolla2)

# %%
import statsmodels.formula.api as smf 
model = smf.ols('	Price ~	Age_08_04 +	KM +	HP +	cc +	Doors +	Gears +	Quarterly_Tax	+ Weight',data=corolla2).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Sun, 14 May 2023   Prob (F-statistic):               0.00
# Time:                        13:53:46   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
round(model.pvalues,6)
# Out:
# Intercept        0.000111
# Age_08_04        0.000000
# KM               0.000000
# HP               0.000000
# cc               0.188239
# Doors            0.981644
# Gears            0.002452
# Quarterly_Tax    0.003290
# Weight           0.000000
# dtype: float64

# %% [markdown]
# # Simple Linear Models

# %%
slr_Doors=smf.ols('Price~Doors',data = corolla2).fit()
slr_Doors.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     49.99
# Date:                Sun, 14 May 2023   Prob (F-statistic):           2.40e-12
# Time:                        13:53:46   Log-Likelihood:                -13765.
# No. Observations:                1435   AIC:                         2.753e+04
# Df Residuals:                    1433   BIC:                         2.755e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7916.1452    407.596     19.422      0.000    7116.596    8715.694
# ...

# %%
slr_cc=smf.ols('Price~cc',data = corolla2).fit()
slr_cc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     22.52
# Date:                Sun, 14 May 2023   Prob (F-statistic):           2.29e-06
# Time:                        13:53:46   Log-Likelihood:                -13779.
# No. Observations:                1435   AIC:                         2.756e+04
# Df Residuals:                    1433   BIC:                         2.757e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9053.5368    363.894     24.880      0.000    8339.715    9767.359
# ...

# %%
slr_Doors_cc=smf.ols('Price~Doors + cc',data = corolla2).fit()
slr_Doors_cc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Sun, 14 May 2023   Prob (F-statistic):           2.55e-15
# Time:                        13:53:46   Log-Likelihood:                -13756.
# No. Observations:                1435   AIC:                         2.752e+04
# Df Residuals:                    1432   BIC:                         2.753e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6568.3395    513.700     12.786      0.000    5560.655    7576.024
# ...

# %% [markdown]
# # Calculating VIF

# %%
rsq_Age = smf.ols('Age_08_04 ~	KM +	HP +	cc + Doors +	Gears +	Quarterly_Tax	+ Weight',data=corolla2).fit().rsquared  
vif_Age = 1/(1-rsq_Age) 

rsq_KM = smf.ols('KM ~ Age_08_04 +	HP +	cc + Doors +	Gears +	Quarterly_Tax	+ Weight',data=corolla2).fit().rsquared  
vif_KM = 1/(1-rsq_KM) 

rsq_HP = smf.ols('HP ~ Age_08_04 +	KM +	cc + Doors +	Gears +	Quarterly_Tax	+ Weight',data=corolla2).fit().rsquared  
vif_HP = 1/(1-rsq_HP) 

rsq_cc = smf.ols('cc ~ Age_08_04 +	KM +	HP + Doors +	Gears +	Quarterly_Tax	+ Weight',data=corolla2).fit().rsquared  
vif_cc = 1/(1-rsq_cc) 

rsq_Doors = smf.ols('Doors ~ Age_08_04 +	KM +	HP + cc +	Gears +	Quarterly_Tax	+ Weight',data=corolla2).fit().rsquared  
vif_Doors = 1/(1-rsq_Doors) 

rsq_Gears = smf.ols('Gears ~ Age_08_04 +	KM +	HP + cc + Doors +	Quarterly_Tax	+ Weight',data=corolla2).fit().rsquared  
vif_Gears = 1/(1-rsq_Gears) 

rsq_Q_Tax = smf.ols('Quarterly_Tax ~ Age_08_04 +	KM +	HP + cc + Doors +	Gears	+ Weight',data=corolla2).fit().rsquared  
vif_Q_Tax = 1/(1-rsq_Q_Tax) 

rsq_Weight = smf.ols('Weight ~ Age_08_04 +	KM +	HP + cc + Doors +	Gears	+ Quarterly_Tax',data=corolla2).fit().rsquared  
vif_Weight = 1/(1-rsq_Weight) 

d1 = {'Variables':['Age','KM','HP','cc','Doors','Gears','Q_Tax','Weight'],'VIF':[vif_Age, vif_KM, vif_HP, vif_cc, vif_Doors, vif_Gears, vif_Q_Tax, vif_Weight]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables       VIF
# 0       Age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        cc  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6     Q_Tax  2.295375
# 7    Weight  2.487180

# %% [markdown]
# # Residual Analysis

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid < -4000))
# Out:
# [array([190, 191, 220, 392, 401, 600, 653, 959])]

# %%
list(np.where(model.resid > 5000))
# Out:
# [array([109, 146, 522])]

# %% [markdown]
# # Residual Plot for Homoscedasticity

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Doors", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# From the above partial Regression plot, the flat line shows that 'Doors' is not contributing to 'Profit'. But I'm not removing 'Doors' because the R-square is already above 85%

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "cc", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics

# %% [markdown]
# ## Detecting Influencers/Outliers

# %% [markdown]
# ## Cook’s Distance 1

# %%
model_influence_1 = model.get_influence()
(c_1, _) = model_influence_1.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(corolla2)), np.round(c_1, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c_1),np.max(c_1))
# Out:
# (80, 78.72950582258932)

# %% [markdown]
# ## High Influence points (1)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = corolla2.shape[1]
n = corolla2.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.020905923344947737

# %% [markdown]
# #### From the above plot, it is evident that data point 80 is an influencer

# %%
corolla2[corolla2.index.isin([80])]
# Out:
#     Price  Age_08_04     KM   HP     cc  Doors  Gears  Quarterly_Tax  Weight
# 80  18950         25  20019  110  16000      5      5            100    1180

# %%
corolla3=corolla2.drop(corolla2.index[[80]],axis=0).reset_index()

# %%
#Drop the original index
corolla3=corolla3.drop(['index'],axis=1)

# %%
corolla3
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1429   7500         69  20544   86  1300      3      5             69    1025
# 1430  10845         72  19000   86  1300      3      5             69    1015
# 1431   8500         71  17016   86  1300      3      5             69    1015
# 1432   7250         70  16916   86  1300      3      5             69    1015
# 1433   6950         76      1  110  1600      5      5             19    1114
#
# [1434 rows x 9 columns]

# %% [markdown]
# # Building 'model2'

# %%
#Exclude variable "WT" and generate R-Squared and AIC values
model2 = smf.ols('	Price ~	Age_08_04 +	KM +	HP +	cc +	Doors +	Gears +	Quarterly_Tax	+ Weight',data=corolla3).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     1172.
# Date:                Sun, 14 May 2023   Prob (F-statistic):               0.00
# Time:                        13:53:54   Log-Likelihood:                -12326.
# No. Observations:                1434   AIC:                         2.467e+04
# Df Residuals:                    1425   BIC:                         2.472e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
(model2.rsquared,model2.aic)
# Out:
# (0.8681163912634055, 24669.363894157)

# %%
#Exclude variable "Doors" and generate R-Squared and AIC values
model3 = smf.ols('	Price ~	Age_08_04 +	KM +	HP +	cc + Gears +	Quarterly_Tax	+ Weight',data=corolla3).fit()

# %%
(model3.rsquared,model3.aic)
# Out:
# (0.8680741306155819, 24667.8233300342)

# %% [markdown]
# ##### Comparing above R-Square and AIC values of model "model2" and model "model3", model "model2" has slightly high R- square and low AIC value hence include variable 'VOL' so that multi collinearity problem would be resolved.

# %% [markdown]
# # Cook’s Distance 2

# %%
model_influence_2 = model2.get_influence()
(c_2, _) = model_influence_2.cooks_distance

# %%
fig= plt.subplots(figsize=(20,8))
plt.stem(np.arange(len(corolla3)),np.round(c_2,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
(np.argmax(c_2),np.max(c_2))
# Out:
# (219, 2.225351365527102)

# %% [markdown]
# ## High Influence points (2)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model2)
plt.show()

# %%
k = corolla3.shape[1]
n = corolla3.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.02092050209205021

# %% [markdown]
# ## From the above plot, it is evident that data point 219 and 958 are influencers

# %%
corolla3[corolla3.index.isin([958,219])]
# Out:
#      Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 219  12450         44  74172  110  1600      5      5            163    1615
# 958   9390         66  50806   86  1300      3      5             19    1480

# %%
#Dropping 220th and 959th observations
corolla4=corolla3.drop(corolla3.index[[219,958]],axis=0)

# %%
#Resetting the index and rearranging the row values
corolla4=corolla4.reset_index()

# %%
corolla4
# Out:
#       index  Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  \
# 0         0  13500         23  46986   90  2000      3      5            210
# 1         1  13750         23  72937   90  2000      3      5            210
# 2         2  13950         24  41711   90  2000      3      5            210
# 3         3  14950         26  48000   90  2000      3      5            210
# 4         4  13750         30  38500   90  2000      3      5            210
# ...     ...    ...        ...    ...  ...   ...    ...    ...            ...
# 1427   1429   7500         69  20544   86  1300      3      5             69
# 1428   1430  10845         72  19000   86  1300      3      5             69
# 1429   1431   8500         71  17016   86  1300      3      5             69
# 1430   1432   7250         70  16916   86  1300      3      5             69
# 1431   1433   6950         76      1  110  1600      5      5             19
#
#       Weight
# 0       1165
# 1       1165
# ...

# %% [markdown]
# # Building 'model4'

# %%
model4 = smf.ols('	Price ~	Age_08_04 +	KM +	HP + cc + Doors + Gears +	Quarterly_Tax	+ Weight',data=corolla4).fit()

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     1355.
# Date:                Sun, 14 May 2023   Prob (F-statistic):               0.00
# Time:                        13:53:57   Log-Likelihood:                -12218.
# No. Observations:                1432   AIC:                         2.445e+04
# Df Residuals:                    1423   BIC:                         2.450e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Cook’s Distance 3

# %%
model_influence_3 = model4.get_influence()
(c_3, _) = model_influence_3.cooks_distance

# %%
fig= plt.subplots(figsize=(20,8))
plt.stem(np.arange(len(corolla4)),np.round(c_3,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
(np.argmax(c_3),np.max(c_3))
# Here Cook's distance of all points is less than 0.5
# Out:
# (598, 0.3168903540145446)

# %% [markdown]
# ## High Influence points (3)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model4)
plt.show()

# %%
k = corolla4.shape[1]
n = corolla4.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.023044692737430168

# %% [markdown]
# # Here, the cutoff for high influence points is showing as 0.0209. But there  are lots of points that are greater than this value. If all of these points are removed, then model would become an overfitted one. So, this model 'model4' is used for predicting for new values.

# %%
model4.rsquared
# Out:
# 0.8839684606741538

# %% [markdown]
# # Predicting for new values

# %%
new_data=pd.DataFrame({'Age_08_04':[25,45,34,26,57,68],'KM':[26025,54869,25468,14250,28973,20185] ,	'HP':[54,90,170,69,102,150] , 'cc':[800,1000,1800,900,1000,1500] ,'Doors':[3,2,5,2,2,4] ,'Gears':[4,5,6,5,6,6], 'Quarterly_Tax':[69,68,45,68,67,71]	,'Weight':[800,900,1800,1000,1200,1500]},index=[1,2,3,4,5,6])
new_data
# Out:
#    Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 1         25  26025   54   800      3      4             69     800
# 2         45  54869   90  1000      2      5             68     900
# 3         34  25468  170  1800      5      6             45    1800
# 4         26  14250   69   900      2      5             68    1000
# 5         57  28973  102  1000      2      6             67    1200
# 6         68  20185  150  1500      4      6             71    1500

# %%
new_data['Predicted'] = model4.predict(new_data)
new_data
# Out:
#    Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight  \
# 1         25  26025   54   800      3      4             69     800
# 2         45  54869   90  1000      2      5             68     900
# 3         34  25468  170  1800      5      6             45    1800
# 4         26  14250   69   900      2      5             68    1000
# 5         57  28973  102  1000      2      6             67    1200
# 6         68  20185  150  1500      4      6             71    1500
#
#       Predicted
# 1   7331.186494
# 2   8799.567160
# 3  37919.384996
# 4  14285.556694
# 5  17964.419902
# 6  25689.830586
